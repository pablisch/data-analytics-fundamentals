# %%
import pandas as pd

# %% [markdown]
# # Data Analytics Fundamentals - Topic 5
#
# Reworking the lesson data using Python

# %%
df = pd.read_csv("data/bpp_topic_5_data/bpp5_joined_csv.csv")
df
# Out:
#                                            Country Name Country Code  \
# 0                                                 Aruba          ABW
# 1                                                 Aruba          ABW
# 2                                                 Aruba          ABW
# 3                                                 Aruba          ABW
# 4                                                 Aruba          ABW
# ...                                                 ...          ...
# 8476  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8477  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8478  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8479  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8480  Middle East, North Africa, Afghanistan & Pakis...          TMN
#
#                     Indicator Name     Indicator Code    Year     Value  \
# ...

# %%
df = df.dropna(subset=["Year"])
df
# Out:
#                                            Country Name Country Code  \
# 0                                                 Aruba          ABW
# 1                                                 Aruba          ABW
# 2                                                 Aruba          ABW
# 3                                                 Aruba          ABW
# 4                                                 Aruba          ABW
# ...                                                 ...          ...
# 8476  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8477  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8478  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8479  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8480  Middle East, North Africa, Afghanistan & Pakis...          TMN
#
#                     Indicator Name     Indicator Code    Year     Value  \
# ...

# %%
df = df.dropna(subset=["Value", "pupils.Value", "spend.Value"], how="all")
df
# Out:
#                                            Country Name Country Code  \
# 0                                                 Aruba          ABW
# 1                                                 Aruba          ABW
# 2                                                 Aruba          ABW
# 3                                                 Aruba          ABW
# 4                                                 Aruba          ABW
# ...                                                 ...          ...
# 8476  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8477  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8478  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8479  Middle East, North Africa, Afghanistan & Pakis...          TMN
# 8480  Middle East, North Africa, Afghanistan & Pakis...          TMN
#
#                     Indicator Name     Indicator Code    Year     Value  \
# ...
