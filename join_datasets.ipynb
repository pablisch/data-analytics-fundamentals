# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from numpy.ma.extras import column_stack
from scipy import stats
import statsmodels.api as sm

from data_source import get_data_frame, get_bpp_5_data, Dataset
from helpers import is_significant, clean_bpp_5_dataframes

# %matplotlib inline
sns.set_theme()

# %%
enrol_df = get_bpp_5_data(Dataset.ENROL)
enrol_df.head(3)
# Out:
# data/bpp_topic_5_data/API_SE.PRM.ENRL.TC.ZS_DS2_en_csv_v2_131293.csv
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  Pupil-teacher ratio, primary
# 1  Africa Eastern and Southern          AFE  Pupil-teacher ratio, primary
# 2                  Afghanistan          AFG  Pupil-teacher ratio, primary
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...      2016  \
# 0  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 2  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  44.58162
#
#        2017      2018  2019  2020  2021  2022  2023  2024  Unnamed: 69
# 0       NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1       NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2  47.98298  48.78979   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [3 rows x 70 columns]

# %%
pupils_df = get_bpp_5_data(Dataset.ENROL)
pupils_df.head(3)
# Out:
# data/bpp_topic_5_data/API_SE.PRM.ENRL.TC.ZS_DS2_en_csv_v2_131293.csv
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  Pupil-teacher ratio, primary
# 1  Africa Eastern and Southern          AFE  Pupil-teacher ratio, primary
# 2                  Afghanistan          AFG  Pupil-teacher ratio, primary
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...      2016  \
# 0  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 2  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  44.58162
#
#        2017      2018  2019  2020  2021  2022  2023  2024  Unnamed: 69
# 0       NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1       NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2  47.98298  48.78979   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [3 rows x 70 columns]

# %%
spend_df = get_bpp_5_data(Dataset.ENROL)
spend_df.head(3)
# Out:
# data/bpp_topic_5_data/API_SE.PRM.ENRL.TC.ZS_DS2_en_csv_v2_131293.csv
#                   Country Name Country Code                Indicator Name  \
# 0                        Aruba          ABW  Pupil-teacher ratio, primary
# 1  Africa Eastern and Southern          AFE  Pupil-teacher ratio, primary
# 2                  Afghanistan          AFG  Pupil-teacher ratio, primary
#
#       Indicator Code  1960  1961  1962  1963  1964  1965  ...      2016  \
# 0  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 1  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...       NaN
# 2  SE.PRM.ENRL.TC.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...  44.58162
#
#        2017      2018  2019  2020  2021  2022  2023  2024  Unnamed: 69
# 0       NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 1       NaN       NaN   NaN   NaN   NaN   NaN   NaN   NaN          NaN
# 2  47.98298  48.78979   NaN   NaN   NaN   NaN   NaN   NaN          NaN
#
# [3 rows x 70 columns]

# %%
enrol_df = clean_bpp_5_dataframes(enrol_df)
enrol_df
# Out:
#       Country Name Country Code                Indicator Name  \
# 2      Afghanistan          AFG  Pupil-teacher ratio, primary
# 7       Arab World          ARB  Pupil-teacher ratio, primary
# 9        Argentina          ARG  Pupil-teacher ratio, primary
# 20      Bangladesh          BGD  Pupil-teacher ratio, primary
# 29          Brazil          BRA  Pupil-teacher ratio, primary
# ...            ...          ...                           ...
# 13027        World          WLD  Pupil-teacher ratio, primary
# 13117        Ghana          GHA  Pupil-teacher ratio, primary
# 13154   Kazakhstan          KAZ  Pupil-teacher ratio, primary
# 13183       Monaco          MCO  Pupil-teacher ratio, primary
# 13212        Nepal          NPL  Pupil-teacher ratio, primary
#
#           Indicator Code  Year     Value
# 2      SE.PRM.ENRL.TC.ZS  1970  41.22332
# 7      SE.PRM.ENRL.TC.ZS  1970  31.30673
# 9      SE.PRM.ENRL.TC.ZS  1970  19.24521
# 20     SE.PRM.ENRL.TC.ZS  1970  46.48234
# ...

# %%
pupils_df = clean_bpp_5_dataframes(pupils_df)
pupils_df
# Out:
#       Country Name Country Code                Indicator Name  \
# 2      Afghanistan          AFG  Pupil-teacher ratio, primary
# 7       Arab World          ARB  Pupil-teacher ratio, primary
# 9        Argentina          ARG  Pupil-teacher ratio, primary
# 20      Bangladesh          BGD  Pupil-teacher ratio, primary
# 29          Brazil          BRA  Pupil-teacher ratio, primary
# ...            ...          ...                           ...
# 13027        World          WLD  Pupil-teacher ratio, primary
# 13117        Ghana          GHA  Pupil-teacher ratio, primary
# 13154   Kazakhstan          KAZ  Pupil-teacher ratio, primary
# 13183       Monaco          MCO  Pupil-teacher ratio, primary
# 13212        Nepal          NPL  Pupil-teacher ratio, primary
#
#           Indicator Code  Year     Value
# 2      SE.PRM.ENRL.TC.ZS  1970  41.22332
# 7      SE.PRM.ENRL.TC.ZS  1970  31.30673
# 9      SE.PRM.ENRL.TC.ZS  1970  19.24521
# 20     SE.PRM.ENRL.TC.ZS  1970  46.48234
# ...

# %%
spend_df = clean_bpp_5_dataframes(spend_df)
spend_df
# Out:
#       Country Name Country Code                Indicator Name  \
# 2      Afghanistan          AFG  Pupil-teacher ratio, primary
# 7       Arab World          ARB  Pupil-teacher ratio, primary
# 9        Argentina          ARG  Pupil-teacher ratio, primary
# 20      Bangladesh          BGD  Pupil-teacher ratio, primary
# 29          Brazil          BRA  Pupil-teacher ratio, primary
# ...            ...          ...                           ...
# 13027        World          WLD  Pupil-teacher ratio, primary
# 13117        Ghana          GHA  Pupil-teacher ratio, primary
# 13154   Kazakhstan          KAZ  Pupil-teacher ratio, primary
# 13183       Monaco          MCO  Pupil-teacher ratio, primary
# 13212        Nepal          NPL  Pupil-teacher ratio, primary
#
#           Indicator Code  Year     Value
# 2      SE.PRM.ENRL.TC.ZS  1970  41.22332
# 7      SE.PRM.ENRL.TC.ZS  1970  31.30673
# 9      SE.PRM.ENRL.TC.ZS  1970  19.24521
# 20     SE.PRM.ENRL.TC.ZS  1970  46.48234
# ...

# %%
enrol_df = enrol_df.rename(columns={"Value": "Enrol_Value"})
pupils_df = pupils_df.rename(columns={"Value": "Pupils_Value"})
spend_df = spend_df.rename(columns={"Value": "Spend_Value"})

# %%
combined_df = (
    enrol_df.merge(
        pupils_df[["Country Code", "Year", "Pupils_Value"]],
        on=["Country Code", "Year"],
        how="left"
    )
    .merge(
        spend_df[["Country Code", "Year", "Spend_Value"]],
        on=["Country Code", "Year"],
        how="left"
    )
)
combined_df
# Out:
#      Country Name Country Code                Indicator Name  \
# 0     Afghanistan          AFG  Pupil-teacher ratio, primary
# 1      Arab World          ARB  Pupil-teacher ratio, primary
# 2       Argentina          ARG  Pupil-teacher ratio, primary
# 3      Bangladesh          BGD  Pupil-teacher ratio, primary
# 4          Brazil          BRA  Pupil-teacher ratio, primary
# ...           ...          ...                           ...
# 8210        World          WLD  Pupil-teacher ratio, primary
# 8211        Ghana          GHA  Pupil-teacher ratio, primary
# 8212   Kazakhstan          KAZ  Pupil-teacher ratio, primary
# 8213       Monaco          MCO  Pupil-teacher ratio, primary
# 8214        Nepal          NPL  Pupil-teacher ratio, primary
#
#          Indicator Code  Year  Enrol_Value  Pupils_Value  Spend_Value
# 0     SE.PRM.ENRL.TC.ZS  1970     41.22332      41.22332     41.22332
# 1     SE.PRM.ENRL.TC.ZS  1970     31.30673      31.30673     31.30673
# ...
